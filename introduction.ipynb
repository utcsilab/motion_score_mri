# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import glob
import os, sys
import h5py
from trajectory_creator import Cart2D_traj_gen, prop2D_traj_gen, ACS_Cart2D_traj_gen
from motion_ops import motion_adjoint, motion_forward, motion_normal

os.environ["TOOLBOX_PATH"] = "/home/blevac/misc/HW/bart-0.6.00"  ## change to YOUR path
sys.path.append("/home/blevac/misc/HW/bart-0.6.00/python")        ## change to YOUR path
os.environ["OMP_NUM_THREADS"] = "1"
from bart import bart

from CG_motion import conjgrad_motion_nufft

# %% [markdown]
# ## Load kspace and coil maps

# %%
device = 'cuda'
ksp_folder = sorted(glob.glob('/csiNAS/mridata/fastmri_brain/multicoil_val/*T2*.h5')) # change to YOUR path
print()
sample_num = 1
ksp_file = ksp_folder[sample_num]
print(ksp_file)

slic = 2
with h5py.File(ksp_file,'r') as cont:
    # print(cont.keys())
    ksp = np.asarray(cont['kspace'][slic])
# Out:
# /csiNAS/mridata/fastmri_brain/multicoil_val/file_brain_AXT2_200_2000021.h5

# %% [markdown]
# ## Reformat synthetic data to (256x256)

# %%
def _expand_shapes(*shapes):

    shapes = [list(shape) for shape in shapes]
    max_ndim = max(len(shape) for shape in shapes)
    shapes_exp = [[1] * (max_ndim - len(shape)) + shape
                  for shape in shapes]

    return tuple(shapes_exp)
    
def resize(input, oshape, ishift=None, oshift=None):
    """Resize with zero-padding or cropping.

    Args:
        input (array): Input array.
        oshape (tuple of ints): Output shape.
        ishift (None or tuple of ints): Input shift.
        oshift (None or tuple of ints): Output shift.

    Returns:
        array: Zero-padded or cropped result.
    """

    ishape1, oshape1 = _expand_shapes(input.shape, oshape)

    if ishape1 == oshape1:
        return input.reshape(oshape)

    if ishift is None:
        ishift = [max(i // 2 - o // 2, 0) for i, o in zip(ishape1, oshape1)]

    if oshift is None:
        oshift = [max(o // 2 - i // 2, 0) for i, o in zip(ishape1, oshape1)]

    copy_shape = [min(i - si, o - so)
                  for i, si, o, so in zip(ishape1, ishift, oshape1, oshift)]
    islice = tuple([slice(si, si + c) for si, c in zip(ishift, copy_shape)])
    oslice = tuple([slice(so, so + c) for so, c in zip(oshift, copy_shape)])

    output = np.zeros(oshape1, dtype=input.dtype)
    input = input.reshape(ishape1)
    output[oslice] = input[islice]

    return output.reshape(oshape)

# write function to take centered fft of image
def fftc(img):
    return np.fft.fftshift(np.fft.fft2(np.fft.ifftshift(img),norm='ortho'))
# write function to take centered ifft of image
def ifftc(img):
    return np.fft.fftshift(np.fft.ifft2(np.fft.ifftshift(img),norm='ortho'))

# %%
H = 384
W = 384
np_gt_coil_imgs = resize(ifftc(ksp), (ksp.shape[0],H,W))[None,...]
H_f = 256
W_f = 256
np_gt_coil_ksp  = resize(fftc(np_gt_coil_imgs), (1,ksp.shape[0],H_f,W_f))
np_gt_coil_imgs = ifftc(np_gt_coil_ksp)
gt_coil_imgs    = torch.tensor(np_gt_coil_imgs)
print(gt_coil_imgs.shape)
# Out:
# torch.Size([1, 16, 256, 256])

# %% [markdown]
# ## Calculate coil maps

# %%
#generate new maps off of cropped ksp
np_gt_coil_ksp = np.transpose(np_gt_coil_ksp,(-2,-1,0,1))
sens = bart(1, 'ecalib -m1 -W -c0', np_gt_coil_ksp) #requires data of the form (Row,Column,None,Coil)<-output of ecalib too, this should then be saved (slice, coil, rows, columns)
new_maps = torch.tensor(sens).permute(-2,-1,0,1)


plt.figure(figsize=(18,6))
for i in range(gt_coil_imgs.shape[1]):
    plt.subplot(2,8,i+1)
    plt.imshow(torch.flipud(abs(gt_coil_imgs[0,i])),cmap='gray')
    plt.axis('off')

plt.tight_layout()


plt.figure(figsize=(18,6))
for i in range(gt_coil_imgs.shape[1]):
    plt.subplot(2,8,i+1)
    plt.imshow(torch.flipud(abs(new_maps[0,i])),cmap='gray')
    plt.axis('off')

plt.tight_layout()
# Out:
# Done.

# %%
print(new_maps.shape)
print(gt_coil_imgs.shape)
gt_img = torch.sum(torch.conj(new_maps.cpu())*gt_coil_imgs.cpu(), axis=1)[:,None,...]
print(gt_img.shape)
plt.figure()
plt.imshow(np.flipud(abs(gt_img[0,0])),cmap='gray')
# Out:
# torch.Size([1, 16, 256, 256])
# torch.Size([1, 16, 256, 256])
# torch.Size([1, 1, 256, 256])

# %% [markdown]
# ## Create motion states and aquisition trajectory

# %%
#Generate GT image
R = 4
TRs = 16
ETL = 16
max = 2.0
N_RO = 256
coords = Cart2D_traj_gen(TRs=TRs, ETL=ETL, N_RO=N_RO, ro_dir='x', ordering='interleave')
ktraj = torch.tensor(coords[0::R]).to(device)
# traj = ACS_Cart2D_traj_gen(TRs=TRs, ETL=ETL, N_RO=N_RO, R=R, ro_dir = 'y', ordering='ACS_random', acs_perc=0.06)
# print(traj.shape)
# ktraj=torch.tensor(np.concatenate((traj[...,1][...,None], traj[...,0][...,None]),axis=-1)).to(device)
print(ktraj.shape)


gt_coil_imgs = gt_coil_imgs.to(device)
gt_dx = torch.tensor(np.random.uniform(-max,max,int(TRs/R))).to(device)
gt_dy = torch.tensor(np.random.uniform(-max,max,int(TRs/R))).to(device)
gt_theta = torch.tensor(np.random.uniform(-max,max,int(TRs/R))).to(device)
maps = new_maps.to(device)
init_maps = torch.ones(gt_coil_imgs.shape).to(device)

# generate motion corrupt measuremnts
y_meas    = motion_forward(image = gt_coil_imgs, s_maps = init_maps, coords = ktraj, angles=gt_theta, dx = gt_dx, dy = gt_dy, device=device)
# Out:
# torch.Size([4, 4096, 2])

# %%
# vizualize sampling patterns
plt.figure(figsize=(6,6))
for i in range(ktraj.shape[0]):
    plt.scatter(ktraj[i,:,1].cpu(), ktraj[i,:,0].cpu(),s=0.2 )

plt.xlabel('kx')
plt.ylabel('ky')
# Out:
# Text(0, 0.5, 'ky')

# %% [markdown]
# ## Do adjoint recon without accounting for motion

# %%
adj_moco_img = motion_adjoint(ksp = y_meas,coords=ktraj, s_maps = maps, angles=torch.zeros_like(gt_theta),dx = torch.zeros_like(gt_dx), dy = torch.zeros_like(gt_dy),img_shape=maps.shape,device=device)

# %%
plt.figure(figsize=(4,4))
plt.title('Motion Corrupt')
plt.imshow(torch.flipud(abs(adj_moco_img.cpu())[0,0]),cmap='gray')
plt.colorbar()
plt.axis('off')

norm = torch.max(abs(adj_moco_img))
print(norm)
# Out:
# tensor(0.0003, device='cuda:0', dtype=torch.float64)

# %% [markdown]
# ## Do CG based Recons

# %% [markdown]
# Note: accounting for motion in the Forward/Adjoint hurts the condition number so convergence is slower for the recon with correct motion estimates. If you're curious just calculate the condition number using power iteration

# %%
# Do recon with known motion states
rhs =  motion_adjoint(ksp = y_meas,coords=ktraj, s_maps = maps, angles= gt_theta,dx = gt_dx, dy = gt_dy,img_shape=maps.shape,device=device)
rhs_scaled = rhs/torch.max(abs(rhs))
known_motion_cg, iter= conjgrad_motion_nufft(x=rhs_scaled, b=rhs_scaled, ktraj=ktraj, maps=maps, thetas=gt_theta, dx=gt_dx, dy=gt_dy, max_iter=35
                                , l2lam=.001, eps=1e-4, verbose=False, complex=True, device=device)

# %%
# Do recon with unknown motion states
rhs =   motion_adjoint(ksp = y_meas,coords=ktraj, s_maps = maps, angles=torch.zeros_like(gt_theta),dx = torch.zeros_like(gt_dx), dy = torch.zeros_like(gt_dy),img_shape=maps.shape,device=device)
rhs_scaled = rhs/torch.max(abs(rhs))
unknown_motion_cg, iter= conjgrad_motion_nufft(x=rhs_scaled, b=rhs_scaled, ktraj=ktraj, maps=maps, thetas=torch.zeros_like(gt_theta), dx=torch.zeros_like(gt_dx), dy=torch.zeros_like(gt_dy), max_iter=35
                                , l2lam=.001, eps=1e-4, verbose=False, complex=True, device=device)

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title('CG Recon (Known Motion)')
plt.imshow(torch.flipud(abs(known_motion_cg.cpu())[0,0]),cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title('CG Recon (Unknown Motion)')
plt.imshow(torch.flipud(abs(unknown_motion_cg.cpu())[0,0]),cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ## Diffusion Motion Correction Recon

# %%
import numpy as np
import torch
from tqdm import tqdm
import matplotlib.pyplot as plt
import os
import argparse
from utils import nrmse
from sampling_funcs import StackedRandomGenerator,ODE_motion_sampler
import pickle
import dnnlib
from torch_utils import distributed as dist
device = 'cuda'

# %%
norm_c = torch.max(abs(gt_img.cpu()))
ksp_norm = y_meas/norm_c
gt_img_norm = gt_img.cuda()/norm_c

# %%
# load network
# net_save = '/csiNAS2/slow/brett/edm_outputs/00027-T2-uncond-ddpmpp-edm-gpus4-batch16-fp32-T2/network-snapshot-010000.pkl' # change to YOUR path
net_save = '/csiNAS2/slow/brett/edm_outputs/network-snapshot-004800.pkl'
if dist.get_rank() != 0:
        torch.distributed.barrier()

# Load network.
dist.print0(f'Loading network from "{net_save}"...')
with dnnlib.util.open_url(net_save, verbose=(dist.get_rank() == 0)) as f:
    net = pickle.load(f)['ema'].to(device)
# Out:
# Loading network from "/csiNAS2/slow/brett/edm_outputs/network-snapshot-004800.pkl"...

# %%
H = 256
W = 256
seed = 0
rnd = StackedRandomGenerator(device, [seed])
latents = rnd.randn([1, 2, H, W], device=device)
class_labels = None
class_idx = None
if net.label_dim:
    class_labels = torch.eye(net.label_dim, device=device)[rnd.randint(net.label_dim, size=[batch_size], device=device)]
if class_idx is not None:
    class_labels[:, :] = 0
    class_labels[:, class_idx] = 1

# %%
img_lss = 1.0
mot_lss = 1.0
num_steps = 300
sigma_max = 5.0
S_noise = 0
motion_est = 1

# %%
net.img_resolution
# Out:
# 256

# %%
image_recon, est_theta, est_dx, est_dy = ODE_motion_sampler(net=net, y=ksp_norm, maps=maps,traj=ktraj, 
                                        latents=latents, img_l_ss=img_lss,motion_l_ss=mot_lss, class_labels=class_labels, 
                                        randn_like=torch.randn_like, num_steps=num_steps, sigma_min=0.002, 
                                        sigma_max=sigma_max, rho=7, S_churn=420, S_min=0, S_max=float('inf'),
                                        S_noise= S_noise, motion_est = motion_est,
                                        gt_img=gt_img_norm, gt_theta=gt_theta, gt_dx=gt_dx, gt_dy=gt_dy, group_ETL=1)
cplx_recon = torch.view_as_complex(image_recon.permute(0,-2,-1,1).contiguous())[None] #shape: [1,1,H,W]
# Out:
# Step:0 , img NRMSE: 38.095, theta NRMSE: 1.001, dx NRMSE: 1.001, dy NRMSE: 1.000
# Step:1 , img NRMSE: 37.490, theta NRMSE: 1.002, dx NRMSE: 1.003, dy NRMSE: 0.999
# Step:2 , img NRMSE: 36.894, theta NRMSE: 1.002, dx NRMSE: 1.005, dy NRMSE: 0.998
# Step:3 , img NRMSE: 36.305, theta NRMSE: 1.002, dx NRMSE: 1.007, dy NRMSE: 0.997
# Step:4 , img NRMSE: 35.724, theta NRMSE: 1.002, dx NRMSE: 1.011, dy NRMSE: 0.996
# Step:5 , img NRMSE: 35.152, theta NRMSE: 1.001, dx NRMSE: 1.015, dy NRMSE: 0.994
# Step:6 , img NRMSE: 34.587, theta NRMSE: 1.001, dx NRMSE: 1.019, dy NRMSE: 0.993
# Step:7 , img NRMSE: 34.030, theta NRMSE: 1.000, dx NRMSE: 1.023, dy NRMSE: 0.991
# Step:8 , img NRMSE: 33.480, theta NRMSE: 0.998, dx NRMSE: 1.028, dy NRMSE: 0.990
# Step:9 , img NRMSE: 32.938, theta NRMSE: 0.997, dx NRMSE: 1.032, dy NRMSE: 0.988
# Step:10 , img NRMSE: 32.404, theta NRMSE: 0.995, dx NRMSE: 1.037, dy NRMSE: 0.987
# Step:11 , img NRMSE: 31.876, theta NRMSE: 0.993, dx NRMSE: 1.041, dy NRMSE: 0.986
# Step:12 , img NRMSE: 31.357, theta NRMSE: 0.992, dx NRMSE: 1.046, dy NRMSE: 0.985
# Step:13 , img NRMSE: 30.844, theta NRMSE: 0.990, dx NRMSE: 1.051, dy NRMSE: 0.984
# Step:14 , img NRMSE: 30.338, theta NRMSE: 0.988, dx NRMSE: 1.055, dy NRMSE: 0.984
# Step:15 , img NRMSE: 29.840, theta NRMSE: 0.987, dx NRMSE: 1.060, dy NRMSE: 0.983
# Step:16 , img NRMSE: 29.348, theta NRMSE: 0.985, dx NRMSE: 1.065, dy NRMSE: 0.983
# Step:17 , img NRMSE: 28.863, theta NRMSE: 0.984, dx NRMSE: 1.070, dy NRMSE: 0.984
# Step:18 , img NRMSE: 28.385, theta NRMSE: 0.982, dx NRMSE: 1.075, dy NRMSE: 0.984
# Step:19 , img NRMSE: 27.914, theta NRMSE: 0.981, dx NRMSE: 1.081, dy NRMSE: 0.985
# Step:20 , img NRMSE: 27.450, theta NRMSE: 0.979, dx NRMSE: 1.086, dy NRMSE: 0.986
# Step:21 , img NRMSE: 26.992, theta NRMSE: 0.978, dx NRMSE: 1.092, dy NRMSE: 0.987
# Step:22 , img NRMSE: 26.540, theta NRMSE: 0.977, dx NRMSE: 1.098, dy NRMSE: 0.988
# Step:23 , img NRMSE: 26.095, theta NRMSE: 0.975, dx NRMSE: 1.104, dy NRMSE: 0.989
# Step:24 , img NRMSE: 25.656, theta NRMSE: 0.974, dx NRMSE: 1.110, dy NRMSE: 0.991
# Step:25 , img NRMSE: 25.224, theta NRMSE: 0.973, dx NRMSE: 1.117, dy NRMSE: 0.993
# Step:26 , img NRMSE: 24.797, theta NRMSE: 0.972, dx NRMSE: 1.124, dy NRMSE: 0.995
# Step:27 , img NRMSE: 24.377, theta NRMSE: 0.970, dx NRMSE: 1.130, dy NRMSE: 0.997
# Step:28 , img NRMSE: 23.963, theta NRMSE: 0.969, dx NRMSE: 1.138, dy NRMSE: 0.999
# Step:29 , img NRMSE: 23.554, theta NRMSE: 0.968, dx NRMSE: 1.145, dy NRMSE: 1.001
# Step:30 , img NRMSE: 23.152, theta NRMSE: 0.966, dx NRMSE: 1.152, dy NRMSE: 1.003
# Step:31 , img NRMSE: 22.756, theta NRMSE: 0.965, dx NRMSE: 1.160, dy NRMSE: 1.006
# Step:32 , img NRMSE: 22.365, theta NRMSE: 0.963, dx NRMSE: 1.167, dy NRMSE: 1.008
# Step:33 , img NRMSE: 21.980, theta NRMSE: 0.961, dx NRMSE: 1.175, dy NRMSE: 1.010
# Step:34 , img NRMSE: 21.600, theta NRMSE: 0.960, dx NRMSE: 1.183, dy NRMSE: 1.012
# Step:35 , img NRMSE: 21.226, theta NRMSE: 0.958, dx NRMSE: 1.191, dy NRMSE: 1.014
# Step:36 , img NRMSE: 20.858, theta NRMSE: 0.956, dx NRMSE: 1.199, dy NRMSE: 1.016
# Step:37 , img NRMSE: 20.495, theta NRMSE: 0.954, dx NRMSE: 1.207, dy NRMSE: 1.018
# Step:38 , img NRMSE: 20.137, theta NRMSE: 0.952, dx NRMSE: 1.215, dy NRMSE: 1.020
# Step:39 , img NRMSE: 19.785, theta NRMSE: 0.950, dx NRMSE: 1.224, dy NRMSE: 1.022
# Step:40 , img NRMSE: 19.437, theta NRMSE: 0.948, dx NRMSE: 1.233, dy NRMSE: 1.023
# Step:41 , img NRMSE: 19.095, theta NRMSE: 0.946, dx NRMSE: 1.243, dy NRMSE: 1.025
# Step:42 , img NRMSE: 18.758, theta NRMSE: 0.944, dx NRMSE: 1.253, dy NRMSE: 1.026
# Step:43 , img NRMSE: 18.427, theta NRMSE: 0.942, dx NRMSE: 1.265, dy NRMSE: 1.027
# Step:44 , img NRMSE: 18.100, theta NRMSE: 0.939, dx NRMSE: 1.277, dy NRMSE: 1.028
# Step:45 , img NRMSE: 17.778, theta NRMSE: 0.937, dx NRMSE: 1.291, dy NRMSE: 1.029
# Step:46 , img NRMSE: 17.460, theta NRMSE: 0.935, dx NRMSE: 1.306, dy NRMSE: 1.030
# Step:47 , img NRMSE: 17.148, theta NRMSE: 0.932, dx NRMSE: 1.322, dy NRMSE: 1.031
# Step:48 , img NRMSE: 16.840, theta NRMSE: 0.930, dx NRMSE: 1.338, dy NRMSE: 1.032
# Step:49 , img NRMSE: 16.537, theta NRMSE: 0.928, dx NRMSE: 1.355, dy NRMSE: 1.032
# Step:50 , img NRMSE: 16.239, theta NRMSE: 0.925, dx NRMSE: 1.373, dy NRMSE: 1.033
# Step:51 , img NRMSE: 15.945, theta NRMSE: 0.923, dx NRMSE: 1.391, dy NRMSE: 1.034
# Step:52 , img NRMSE: 15.656, theta NRMSE: 0.920, dx NRMSE: 1.410, dy NRMSE: 1.035
# Step:53 , img NRMSE: 15.371, theta NRMSE: 0.917, dx NRMSE: 1.429, dy NRMSE: 1.035
# Step:54 , img NRMSE: 15.090, theta NRMSE: 0.914, dx NRMSE: 1.448, dy NRMSE: 1.036
# Step:55 , img NRMSE: 14.814, theta NRMSE: 0.912, dx NRMSE: 1.468, dy NRMSE: 1.037
# Step:56 , img NRMSE: 14.542, theta NRMSE: 0.909, dx NRMSE: 1.488, dy NRMSE: 1.037
# Step:57 , img NRMSE: 14.274, theta NRMSE: 0.906, dx NRMSE: 1.508, dy NRMSE: 1.037
# Step:58 , img NRMSE: 14.011, theta NRMSE: 0.902, dx NRMSE: 1.528, dy NRMSE: 1.038
# Step:59 , img NRMSE: 13.751, theta NRMSE: 0.899, dx NRMSE: 1.548, dy NRMSE: 1.038
# Step:60 , img NRMSE: 13.496, theta NRMSE: 0.896, dx NRMSE: 1.568, dy NRMSE: 1.038
# Step:61 , img NRMSE: 13.244, theta NRMSE: 0.892, dx NRMSE: 1.589, dy NRMSE: 1.038
# Step:62 , img NRMSE: 12.997, theta NRMSE: 0.889, dx NRMSE: 1.608, dy NRMSE: 1.038
# Step:63 , img NRMSE: 12.753, theta NRMSE: 0.885, dx NRMSE: 1.628, dy NRMSE: 1.038
# Step:64 , img NRMSE: 12.514, theta NRMSE: 0.881, dx NRMSE: 1.647, dy NRMSE: 1.037
# Step:65 , img NRMSE: 12.278, theta NRMSE: 0.877, dx NRMSE: 1.665, dy NRMSE: 1.037
# Step:66 , img NRMSE: 12.045, theta NRMSE: 0.873, dx NRMSE: 1.683, dy NRMSE: 1.036
# Step:67 , img NRMSE: 11.817, theta NRMSE: 0.869, dx NRMSE: 1.700, dy NRMSE: 1.036
# Step:68 , img NRMSE: 11.592, theta NRMSE: 0.865, dx NRMSE: 1.715, dy NRMSE: 1.035
# Step:69 , img NRMSE: 11.371, theta NRMSE: 0.860, dx NRMSE: 1.730, dy NRMSE: 1.034
# Step:70 , img NRMSE: 11.153, theta NRMSE: 0.856, dx NRMSE: 1.744, dy NRMSE: 1.033
# Step:71 , img NRMSE: 10.939, theta NRMSE: 0.852, dx NRMSE: 1.757, dy NRMSE: 1.032
# Step:72 , img NRMSE: 10.729, theta NRMSE: 0.847, dx NRMSE: 1.770, dy NRMSE: 1.031
# Step:73 , img NRMSE: 10.522, theta NRMSE: 0.842, dx NRMSE: 1.781, dy NRMSE: 1.029
# Step:74 , img NRMSE: 10.318, theta NRMSE: 0.838, dx NRMSE: 1.792, dy NRMSE: 1.028
# Step:75 , img NRMSE: 10.117, theta NRMSE: 0.833, dx NRMSE: 1.803, dy NRMSE: 1.027
# Step:76 , img NRMSE: 9.920, theta NRMSE: 0.828, dx NRMSE: 1.813, dy NRMSE: 1.025
# Step:77 , img NRMSE: 9.726, theta NRMSE: 0.824, dx NRMSE: 1.823, dy NRMSE: 1.024
# Step:78 , img NRMSE: 9.535, theta NRMSE: 0.819, dx NRMSE: 1.832, dy NRMSE: 1.022
# Step:79 , img NRMSE: 9.348, theta NRMSE: 0.814, dx NRMSE: 1.842, dy NRMSE: 1.021
# Step:80 , img NRMSE: 9.163, theta NRMSE: 0.809, dx NRMSE: 1.850, dy NRMSE: 1.020
# Step:81 , img NRMSE: 8.982, theta NRMSE: 0.803, dx NRMSE: 1.859, dy NRMSE: 1.018
# Step:82 , img NRMSE: 8.803, theta NRMSE: 0.798, dx NRMSE: 1.867, dy NRMSE: 1.017
# Step:83 , img NRMSE: 8.628, theta NRMSE: 0.793, dx NRMSE: 1.875, dy NRMSE: 1.016
# Step:84 , img NRMSE: 8.456, theta NRMSE: 0.788, dx NRMSE: 1.882, dy NRMSE: 1.015
# Step:85 , img NRMSE: 8.286, theta NRMSE: 0.782, dx NRMSE: 1.889, dy NRMSE: 1.013
# Step:86 , img NRMSE: 8.119, theta NRMSE: 0.776, dx NRMSE: 1.896, dy NRMSE: 1.012
# Step:87 , img NRMSE: 7.956, theta NRMSE: 0.771, dx NRMSE: 1.903, dy NRMSE: 1.011
# Step:88 , img NRMSE: 7.795, theta NRMSE: 0.765, dx NRMSE: 1.910, dy NRMSE: 1.010
# Step:89 , img NRMSE: 7.636, theta NRMSE: 0.759, dx NRMSE: 1.917, dy NRMSE: 1.009
# Step:90 , img NRMSE: 7.481, theta NRMSE: 0.753, dx NRMSE: 1.923, dy NRMSE: 1.007
# Step:91 , img NRMSE: 7.328, theta NRMSE: 0.747, dx NRMSE: 1.929, dy NRMSE: 1.006
# Step:92 , img NRMSE: 7.178, theta NRMSE: 0.740, dx NRMSE: 1.935, dy NRMSE: 1.005
# Step:93 , img NRMSE: 7.030, theta NRMSE: 0.734, dx NRMSE: 1.941, dy NRMSE: 1.004
# Step:94 , img NRMSE: 6.885, theta NRMSE: 0.727, dx NRMSE: 1.946, dy NRMSE: 1.003
# Step:95 , img NRMSE: 6.743, theta NRMSE: 0.721, dx NRMSE: 1.952, dy NRMSE: 1.002
# Step:96 , img NRMSE: 6.603, theta NRMSE: 0.714, dx NRMSE: 1.957, dy NRMSE: 1.000
# Step:97 , img NRMSE: 6.465, theta NRMSE: 0.707, dx NRMSE: 1.963, dy NRMSE: 0.999
# Step:98 , img NRMSE: 6.330, theta NRMSE: 0.700, dx NRMSE: 1.968, dy NRMSE: 0.998
# Step:99 , img NRMSE: 6.197, theta NRMSE: 0.693, dx NRMSE: 1.973, dy NRMSE: 0.997
# Step:100 , img NRMSE: 6.067, theta NRMSE: 0.686, dx NRMSE: 1.979, dy NRMSE: 0.996
# Step:101 , img NRMSE: 5.939, theta NRMSE: 0.678, dx NRMSE: 1.984, dy NRMSE: 0.995
# Step:102 , img NRMSE: 5.813, theta NRMSE: 0.671, dx NRMSE: 1.989, dy NRMSE: 0.994
# Step:103 , img NRMSE: 5.690, theta NRMSE: 0.663, dx NRMSE: 1.994, dy NRMSE: 0.993
# Step:104 , img NRMSE: 5.569, theta NRMSE: 0.655, dx NRMSE: 1.998, dy NRMSE: 0.992
# Step:105 , img NRMSE: 5.450, theta NRMSE: 0.647, dx NRMSE: 2.003, dy NRMSE: 0.991
# Step:106 , img NRMSE: 5.333, theta NRMSE: 0.639, dx NRMSE: 2.007, dy NRMSE: 0.990
# Step:107 , img NRMSE: 5.218, theta NRMSE: 0.630, dx NRMSE: 2.012, dy NRMSE: 0.989
# Step:108 , img NRMSE: 5.106, theta NRMSE: 0.622, dx NRMSE: 2.015, dy NRMSE: 0.989
# Step:109 , img NRMSE: 4.995, theta NRMSE: 0.613, dx NRMSE: 2.019, dy NRMSE: 0.988
# Step:110 , img NRMSE: 4.887, theta NRMSE: 0.604, dx NRMSE: 2.022, dy NRMSE: 0.987
# Step:111 , img NRMSE: 4.780, theta NRMSE: 0.596, dx NRMSE: 2.025, dy NRMSE: 0.987
# Step:112 , img NRMSE: 4.676, theta NRMSE: 0.587, dx NRMSE: 2.028, dy NRMSE: 0.987
# Step:113 , img NRMSE: 4.574, theta NRMSE: 0.578, dx NRMSE: 2.030, dy NRMSE: 0.986
# Step:114 , img NRMSE: 4.473, theta NRMSE: 0.568, dx NRMSE: 2.032, dy NRMSE: 0.986
# Step:115 , img NRMSE: 4.375, theta NRMSE: 0.559, dx NRMSE: 2.034, dy NRMSE: 0.986
# Step:116 , img NRMSE: 4.278, theta NRMSE: 0.550, dx NRMSE: 2.035, dy NRMSE: 0.986
# Step:117 , img NRMSE: 4.183, theta NRMSE: 0.540, dx NRMSE: 2.036, dy NRMSE: 0.986
# Step:118 , img NRMSE: 4.090, theta NRMSE: 0.530, dx NRMSE: 2.037, dy NRMSE: 0.986
# Step:119 , img NRMSE: 3.999, theta NRMSE: 0.521, dx NRMSE: 2.038, dy NRMSE: 0.987
# Step:120 , img NRMSE: 3.909, theta NRMSE: 0.511, dx NRMSE: 2.039, dy NRMSE: 0.987
# Step:121 , img NRMSE: 3.822, theta NRMSE: 0.501, dx NRMSE: 2.040, dy NRMSE: 0.988
# Step:122 , img NRMSE: 3.736, theta NRMSE: 0.491, dx NRMSE: 2.041, dy NRMSE: 0.988
# Step:123 , img NRMSE: 3.651, theta NRMSE: 0.481, dx NRMSE: 2.041, dy NRMSE: 0.989
# Step:124 , img NRMSE: 3.569, theta NRMSE: 0.471, dx NRMSE: 2.042, dy NRMSE: 0.990
# Step:125 , img NRMSE: 3.488, theta NRMSE: 0.460, dx NRMSE: 2.042, dy NRMSE: 0.991
# Step:126 , img NRMSE: 3.409, theta NRMSE: 0.450, dx NRMSE: 2.043, dy NRMSE: 0.992
# Step:127 , img NRMSE: 3.331, theta NRMSE: 0.440, dx NRMSE: 2.043, dy NRMSE: 0.993
# Step:128 , img NRMSE: 3.255, theta NRMSE: 0.429, dx NRMSE: 2.044, dy NRMSE: 0.994
# Step:129 , img NRMSE: 3.180, theta NRMSE: 0.419, dx NRMSE: 2.044, dy NRMSE: 0.996
# Step:130 , img NRMSE: 3.107, theta NRMSE: 0.408, dx NRMSE: 2.045, dy NRMSE: 0.997
# Step:131 , img NRMSE: 3.036, theta NRMSE: 0.398, dx NRMSE: 2.045, dy NRMSE: 0.998
# Step:132 , img NRMSE: 2.965, theta NRMSE: 0.387, dx NRMSE: 2.046, dy NRMSE: 0.999
# Step:133 , img NRMSE: 2.897, theta NRMSE: 0.376, dx NRMSE: 2.046, dy NRMSE: 1.001
# Step:134 , img NRMSE: 2.830, theta NRMSE: 0.366, dx NRMSE: 2.046, dy NRMSE: 1.002
# Step:135 , img NRMSE: 2.764, theta NRMSE: 0.355, dx NRMSE: 2.047, dy NRMSE: 1.003
# Step:136 , img NRMSE: 2.700, theta NRMSE: 0.344, dx NRMSE: 2.048, dy NRMSE: 1.004
# Step:137 , img NRMSE: 2.637, theta NRMSE: 0.333, dx NRMSE: 2.049, dy NRMSE: 1.005
# Step:138 , img NRMSE: 2.575, theta NRMSE: 0.322, dx NRMSE: 2.050, dy NRMSE: 1.007
# Step:139 , img NRMSE: 2.515, theta NRMSE: 0.312, dx NRMSE: 2.050, dy NRMSE: 1.008
# Step:140 , img NRMSE: 2.456, theta NRMSE: 0.301, dx NRMSE: 2.051, dy NRMSE: 1.009
# Step:141 , img NRMSE: 2.398, theta NRMSE: 0.290, dx NRMSE: 2.052, dy NRMSE: 1.010
# Step:142 , img NRMSE: 2.341, theta NRMSE: 0.280, dx NRMSE: 2.053, dy NRMSE: 1.011
# Step:143 , img NRMSE: 2.286, theta NRMSE: 0.269, dx NRMSE: 2.053, dy NRMSE: 1.012
# Step:144 , img NRMSE: 2.232, theta NRMSE: 0.259, dx NRMSE: 2.053, dy NRMSE: 1.013
# Step:145 , img NRMSE: 2.180, theta NRMSE: 0.249, dx NRMSE: 2.054, dy NRMSE: 1.014
# Step:146 , img NRMSE: 2.128, theta NRMSE: 0.239, dx NRMSE: 2.054, dy NRMSE: 1.015
# Step:147 , img NRMSE: 2.078, theta NRMSE: 0.230, dx NRMSE: 2.054, dy NRMSE: 1.016
# Step:148 , img NRMSE: 2.028, theta NRMSE: 0.220, dx NRMSE: 2.054, dy NRMSE: 1.017
# Step:149 , img NRMSE: 1.980, theta NRMSE: 0.211, dx NRMSE: 2.054, dy NRMSE: 1.018
# Step:150 , img NRMSE: 1.933, theta NRMSE: 0.202, dx NRMSE: 2.054, dy NRMSE: 1.019
# Step:151 , img NRMSE: 1.888, theta NRMSE: 0.194, dx NRMSE: 2.054, dy NRMSE: 1.020
# Step:152 , img NRMSE: 1.843, theta NRMSE: 0.185, dx NRMSE: 2.054, dy NRMSE: 1.020
# Step:153 , img NRMSE: 1.799, theta NRMSE: 0.177, dx NRMSE: 2.054, dy NRMSE: 1.021
# Step:154 , img NRMSE: 1.757, theta NRMSE: 0.170, dx NRMSE: 2.054, dy NRMSE: 1.022
# Step:155 , img NRMSE: 1.715, theta NRMSE: 0.162, dx NRMSE: 2.054, dy NRMSE: 1.022
# Step:156 , img NRMSE: 1.674, theta NRMSE: 0.155, dx NRMSE: 2.053, dy NRMSE: 1.023
# Step:157 , img NRMSE: 1.635, theta NRMSE: 0.149, dx NRMSE: 2.053, dy NRMSE: 1.024
# Step:158 , img NRMSE: 1.596, theta NRMSE: 0.142, dx NRMSE: 2.053, dy NRMSE: 1.024
# Step:159 , img NRMSE: 1.559, theta NRMSE: 0.136, dx NRMSE: 2.052, dy NRMSE: 1.025
# Step:160 , img NRMSE: 1.522, theta NRMSE: 0.131, dx NRMSE: 2.052, dy NRMSE: 1.025
# Step:161 , img NRMSE: 1.487, theta NRMSE: 0.125, dx NRMSE: 2.051, dy NRMSE: 1.026
# Step:162 , img NRMSE: 1.452, theta NRMSE: 0.120, dx NRMSE: 2.051, dy NRMSE: 1.026
# Step:163 , img NRMSE: 1.418, theta NRMSE: 0.116, dx NRMSE: 2.051, dy NRMSE: 1.027
# Step:164 , img NRMSE: 1.385, theta NRMSE: 0.112, dx NRMSE: 2.050, dy NRMSE: 1.027
# Step:165 , img NRMSE: 1.353, theta NRMSE: 0.108, dx NRMSE: 2.050, dy NRMSE: 1.028
# Step:166 , img NRMSE: 1.322, theta NRMSE: 0.104, dx NRMSE: 2.050, dy NRMSE: 1.028
# Step:167 , img NRMSE: 1.292, theta NRMSE: 0.101, dx NRMSE: 2.049, dy NRMSE: 1.029
# Step:168 , img NRMSE: 1.262, theta NRMSE: 0.098, dx NRMSE: 2.049, dy NRMSE: 1.029
# Step:169 , img NRMSE: 1.234, theta NRMSE: 0.095, dx NRMSE: 2.049, dy NRMSE: 1.030
# Step:170 , img NRMSE: 1.206, theta NRMSE: 0.093, dx NRMSE: 2.048, dy NRMSE: 1.030
# Step:171 , img NRMSE: 1.179, theta NRMSE: 0.091, dx NRMSE: 2.048, dy NRMSE: 1.031
# Step:172 , img NRMSE: 1.153, theta NRMSE: 0.089, dx NRMSE: 2.048, dy NRMSE: 1.031
# Step:173 , img NRMSE: 1.128, theta NRMSE: 0.087, dx NRMSE: 2.047, dy NRMSE: 1.031
# Step:174 , img NRMSE: 1.103, theta NRMSE: 0.086, dx NRMSE: 2.047, dy NRMSE: 1.032
# Step:175 , img NRMSE: 1.079, theta NRMSE: 0.085, dx NRMSE: 2.047, dy NRMSE: 1.032
# Step:176 , img NRMSE: 1.056, theta NRMSE: 0.084, dx NRMSE: 2.047, dy NRMSE: 1.032
# Step:177 , img NRMSE: 1.034, theta NRMSE: 0.083, dx NRMSE: 2.046, dy NRMSE: 1.032
# Step:178 , img NRMSE: 1.012, theta NRMSE: 0.082, dx NRMSE: 2.046, dy NRMSE: 1.033
# Step:179 , img NRMSE: 0.991, theta NRMSE: 0.082, dx NRMSE: 2.046, dy NRMSE: 1.033
# Step:180 , img NRMSE: 0.971, theta NRMSE: 0.081, dx NRMSE: 2.046, dy NRMSE: 1.033
# Step:181 , img NRMSE: 0.951, theta NRMSE: 0.081, dx NRMSE: 2.045, dy NRMSE: 1.033
# Step:182 , img NRMSE: 0.932, theta NRMSE: 0.080, dx NRMSE: 2.045, dy NRMSE: 1.033
# Step:183 , img NRMSE: 0.914, theta NRMSE: 0.080, dx NRMSE: 2.045, dy NRMSE: 1.034
# Step:184 , img NRMSE: 0.896, theta NRMSE: 0.080, dx NRMSE: 2.045, dy NRMSE: 1.034
# Step:185 , img NRMSE: 0.879, theta NRMSE: 0.080, dx NRMSE: 2.045, dy NRMSE: 1.034
# Step:186 , img NRMSE: 0.863, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:187 , img NRMSE: 0.847, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:188 , img NRMSE: 0.831, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:189 , img NRMSE: 0.817, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:190 , img NRMSE: 0.803, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:191 , img NRMSE: 0.789, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:192 , img NRMSE: 0.776, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:193 , img NRMSE: 0.763, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:194 , img NRMSE: 0.751, theta NRMSE: 0.080, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:195 , img NRMSE: 0.739, theta NRMSE: 0.080, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:196 , img NRMSE: 0.728, theta NRMSE: 0.080, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:197 , img NRMSE: 0.718, theta NRMSE: 0.080, dx NRMSE: 2.044, dy NRMSE: 1.034
# Step:198 , img NRMSE: 0.707, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.033
# Step:199 , img NRMSE: 0.698, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.033
# Step:200 , img NRMSE: 0.688, theta NRMSE: 0.079, dx NRMSE: 2.044, dy NRMSE: 1.033
# Step:201 , img NRMSE: 0.679, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:202 , img NRMSE: 0.671, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:203 , img NRMSE: 0.662, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:204 , img NRMSE: 0.655, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:205 , img NRMSE: 0.647, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:206 , img NRMSE: 0.640, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:207 , img NRMSE: 0.633, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:208 , img NRMSE: 0.627, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:209 , img NRMSE: 0.621, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:210 , img NRMSE: 0.615, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.033
# Step:211 , img NRMSE: 0.609, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:212 , img NRMSE: 0.604, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:213 , img NRMSE: 0.599, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:214 , img NRMSE: 0.594, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:215 , img NRMSE: 0.590, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:216 , img NRMSE: 0.585, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:217 , img NRMSE: 0.581, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:218 , img NRMSE: 0.577, theta NRMSE: 0.079, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:219 , img NRMSE: 0.574, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:220 , img NRMSE: 0.570, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:221 , img NRMSE: 0.567, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.032
# Step:222 , img NRMSE: 0.564, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.031
# Step:223 , img NRMSE: 0.561, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.031
# Step:224 , img NRMSE: 0.559, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.031
# Step:225 , img NRMSE: 0.556, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.031
# Step:226 , img NRMSE: 0.554, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.031
# Step:227 , img NRMSE: 0.551, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.031
# Step:228 , img NRMSE: 0.549, theta NRMSE: 0.078, dx NRMSE: 2.043, dy NRMSE: 1.031
# Step:229 , img NRMSE: 0.547, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.031
# Step:230 , img NRMSE: 0.546, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.030
# Step:231 , img NRMSE: 0.544, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.030
# Step:232 , img NRMSE: 0.542, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.030
# Step:233 , img NRMSE: 0.541, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.030
# Step:234 , img NRMSE: 0.539, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.030
# Step:235 , img NRMSE: 0.538, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.030
# Step:236 , img NRMSE: 0.537, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.030
# Step:237 , img NRMSE: 0.536, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.029
# Step:238 , img NRMSE: 0.535, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.029
# Step:239 , img NRMSE: 0.534, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.029
# Step:240 , img NRMSE: 0.533, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.029
# Step:241 , img NRMSE: 0.532, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.029
# Step:242 , img NRMSE: 0.531, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.029
# Step:243 , img NRMSE: 0.530, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.029
# Step:244 , img NRMSE: 0.530, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.029
# Step:245 , img NRMSE: 0.529, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.028
# Step:246 , img NRMSE: 0.528, theta NRMSE: 0.078, dx NRMSE: 2.044, dy NRMSE: 1.028
# Step:247 , img NRMSE: 0.528, theta NRMSE: 0.077, dx NRMSE: 2.044, dy NRMSE: 1.028
# Step:248 , img NRMSE: 0.527, theta NRMSE: 0.077, dx NRMSE: 2.044, dy NRMSE: 1.028
# Step:249 , img NRMSE: 0.527, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.028
# Step:250 , img NRMSE: 0.526, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.028
# Step:251 , img NRMSE: 0.526, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.028
# Step:252 , img NRMSE: 0.526, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.028
# Step:253 , img NRMSE: 0.525, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:254 , img NRMSE: 0.525, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:255 , img NRMSE: 0.525, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:256 , img NRMSE: 0.524, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:257 , img NRMSE: 0.524, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:258 , img NRMSE: 0.524, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:259 , img NRMSE: 0.524, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:260 , img NRMSE: 0.524, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:261 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.027
# Step:262 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.026
# Step:263 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.026
# Step:264 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.026
# Step:265 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.026
# Step:266 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.026
# Step:267 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.026
# Step:268 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.026
# Step:269 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.026
# Step:270 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:271 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:272 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:273 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:274 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:275 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:276 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:277 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:278 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.025
# Step:279 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:280 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:281 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:282 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:283 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:284 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:285 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:286 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:287 , img NRMSE: 0.522, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:288 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.024
# Step:289 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:290 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:291 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:292 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:293 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:294 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:295 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:296 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:297 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:298 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.023
# Step:299 , img NRMSE: 0.523, theta NRMSE: 0.077, dx NRMSE: 2.045, dy NRMSE: 1.022

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title('GT')
plt.imshow(torch.flipud(abs(gt_img_norm[0,0].cpu())), cmap = 'gray')
plt.axis('off')
plt.subplot(1,2,2)
plt.title('MI Diffusion Recon')
plt.imshow(torch.flipud(abs(cplx_recon[0,0].cpu())), cmap = 'gray')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
plt.figure(figsize=(12,3))
plt.subplot(1,3,1)
plt.title('Rotation')
plt.plot(gt_theta.cpu(),label='gt')
plt.plot(est_theta.detach().cpu(),label='est')
plt.plot(gt_theta.cpu()-est_theta.detach().cpu(),label='error')
plt.xlabel('TR')
plt.subplot(1,3,2)
plt.title('x-translation')
plt.plot(gt_dx.cpu(),label='gt')
plt.plot(est_dx.detach().cpu(),label='est')
plt.plot(gt_dx.cpu()-est_dx.detach().cpu(),label='error')
plt.xlabel('TR')
plt.subplot(1,3,3)
plt.title('y-translation')
plt.plot(gt_dy.cpu(),label='gt')
plt.plot(est_dy.detach().cpu(),label='est')
plt.plot(gt_dy.cpu()-est_dy.detach().cpu(),label='error')
plt.xlabel('TR')
# Out:
# Text(0.5, 0, 'TR')
